# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you find **at least two datasets** on the web which are related, and that you visualize these datasets to answer the assignment question. You are free to utilize datasets with any location or domain, the usage of **Ann Arbor sports and athletics** datasets in the example is just a suggestion.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * You must state a question you are seeking to answer with your visualizations.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together as an example! [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
# %matplotlib widget

# We can bring in some other libraries we will need too, including the 
# matplotlib animation module
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %%
n = 10000
x = np.random.randn(n)

# %%
# create the function that will do the plotting, where curr is the current frame
def update(curr):
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == n: 
        a.event_source.stop()
    
    # What is a? Well, it's an object that we'll define in a bit, and it will
    # sit outside of this function but we can still access it since python allows
    # us to access variables in the global scope.
    
    # Now on to the work. First thing we want to do is clear the current axes.
    # We can do this with plt.cla().
    plt.cla()
    
    # Now I jut want to plot a histogram. I'm going to set my bins to a predictable
    # value so it doesn't jump around, but you can play with this
    bins = np.arange(-4, 4, 0.5)
    
    # Then we just make the hist() using the current frame number which was passed
    # into the function and our global values array
    plt.hist(x[:curr], bins=bins)
    
    # Set the axes limits
    plt.axis([-4,4,0,10])
    
    # And add some nice labels throughout
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n = {}'.format(curr), [3,27])

# %%
# Quick to start
#a = animation.FuncAnimation(plt.figure(), update, interval=1)

# Now tell the widget back end it's time to show!
#plt.show()

# %%
import pandas as pd
data_oil = pd.read_excel('assets/oil.xls', sheet_name = 'Data 1')
data_cancer = pd.read_excel('assets/cancer.xlsx')
data_population = pd.read_csv('assets/population.csv',header = 9, sep=',')

# %%
#data_population

# %%
data_oil.head()
# Out:
#       Back to Contents  \
# 0            Sourcekey
# 1                 Date
# 2  1920-01-15 00:00:00
# 3  1920-02-15 00:00:00
# 4  1920-03-15 00:00:00
#
#   Data 1: U.S. Exports of Crude Oil and Petroleum Products  \
# 0                                           MTTEXUS1
# 1  U.S. Exports of Crude Oil and Petroleum Produc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      Unnamed: 2  \
# 0                                      MCREXUS1
# 1  U.S. Exports of Crude Oil (Thousand Barrels)
# 2                                           469
# 3                                           853
# 4                                           892
#
#                                           Unnamed: 3  \
# 0                                           MNGEXUS1
# 1  U.S. Exports of Hydrocarbon Gas Liquids (Thous...
# ...

# %%
data_cancer.head()
# Out:
#   Cancer id                                       Cancer label  Population id  \
# 0       1_0  All sites excl. non-melanoma skin cancer, Lip,...          84000
# 1       1_0  All sites excl. non-melanoma skin cancer, Lip,...          84000
# 2       1_0  All sites excl. non-melanoma skin cancer, Lip,...          84000
# 3       1_0  All sites excl. non-melanoma skin cancer, Lip,...          84000
# 4       1_0  All sites excl. non-melanoma skin cancer, Lip,...          84000
#
#   Country label  Sex  Type  Year  ASR (World)  Crude rate  Cumulative risk  \
# 0           USA    1     0  1975   306.377121  340.554198              NaN
# 1           USA    1     0  1976   311.103585  348.319799              NaN
# 2           USA    1     0  1977   314.247330  353.959170              NaN
# 3           USA    1     0  1978   317.157316  359.541643              NaN
# 4           USA    1     0  1979   319.513588  365.118365              NaN
#
#    Total
# 0  46185
# 1  47581
# 2  48725
# ...

# %%
#$list(data_oil.columns)

# %%
#we only want to work with the Crude Oil and Petroleum Products:
data_oil_1 = data_oil[['Back to Contents','Data 1: U.S. Exports of Crude Oil and Petroleum Products']]
data_oil_1.head()
# Out:
#       Back to Contents  \
# 0            Sourcekey
# 1                 Date
# 2  1920-01-15 00:00:00
# 3  1920-02-15 00:00:00
# 4  1920-03-15 00:00:00
#
#   Data 1: U.S. Exports of Crude Oil and Petroleum Products
# 0                                           MTTEXUS1
# 1  U.S. Exports of Crude Oil and Petroleum Produc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_1 = pd.DataFrame(data_oil_1[734::])
df_1 = df_1.rename(columns={'Back to Contents':'Dates','Data 1: U.S. Exports of Crude Oil and Petroleum Products':'Exports_total'})
#This  'Exports_total' columns is given in Thousands of Barrels and we will remember that at the end.
#Now, we will transform this dataset by month in a dataset by year
df_1['Dates'] = pd.to_datetime(df_1['Dates'])
df_1['Year'] = df_1['Dates'].dt.year
df_yearly_sum = df_1.groupby(['Year'])['Exports_total'].sum().reset_index()
df_y_1 = df_yearly_sum

#df_y_1['logExports'] = [np.log(float(x)) for x in df_y_1['Exports_total']]

# %%
df_y_1[df_y_1["Year"]==1995]
#Ok, the Year is given by integer
# Out:
#     Year Exports_total
# 14  1995        346477

# %%
#preparing the second dataset:
data_cancer_1 = data_cancer[['Year',"Total"]]
data_cancer_1.head()
# Out:
#    Year  Total
# 0  1975  46185
# 1  1976  47581
# 2  1977  48725
# 3  1978  49932
# 4  1979  51207

# %%
data_cancer_1[data_cancer_1["Year"]==1975].sum()
# Out:
# Year      3950
# Total    94146
# dtype: int64

# %%
df_cancer_yearly = data_cancer_1.groupby(['Year'])['Total'].sum().reset_index()
df_y_2 = df_cancer_yearly.rename(columns={'Total':'Cases_total'})
#It gives the total by year: 
df_y_2.head()
# Out:
#    Year  Cases_total
# 0  1975        94146
# 1  1976        95348
# 2  1977        97141
# 3  1978        98652
# 4  1979       101022

# %%
data_population.head()
# Out:
#          date   Population   Annual % Change
# 0  1950-12-31    148281550               NaN
# 1  1951-12-31    150598453              1.56
# 2  1952-12-31    152941727              1.56
# 3  1953-12-31    155451199              1.64
# 4  1954-12-31    158205873              1.77

# %%
df_3 = data_population[['date',' Population']]
df_3['date'] = pd.to_datetime(df_3['date'])
df_3['Population_M'] = round(df_3[' Population']/1000000, 2)
df_3.head()
#df_3['date'].iloc[[2]].dt.year #transformed to datetime object
df_3['Year'] = df_3['date'].dt.year
df_3.head()

#df_3['date'].iloc[[2]].dt.year #now this number is integer, as well as the previous datasets.
# Out:
#         date   Population  Population_M  Year
# 0 1950-12-31    148281550        148.28  1950
# 1 1951-12-31    150598453        150.60  1951
# 2 1952-12-31    152941727        152.94  1952
# 3 1953-12-31    155451199        155.45  1953
# 4 1954-12-31    158205873        158.21  1954

# %%
#verifying the NaN values:
print(df_y_1.isna().sum())
print(df_y_2.isna().sum())
print(df_3.isna().sum())
# Out:
# Year             0
# Exports_total    0
# dtype: int64
# Year           0
# Cases_total    0
# dtype: int64
# date            0
#  Population     0
# Population_M    0
# Year            0
# dtype: int64

# %%
#Now we can put all date together to see where is the itersection among the dataframes to construct a relevante data:
#First, let us put together the oil data with the cancer data based on the Year these datasets have in common:

df = pd.merge(df_y_1,df_y_2, on ='Year')
df = pd.merge(df, df_3[['Year','Population_M']], on = 'Year')
df['Cumulative_export'] = df['Exports_total'].cumsum(axis = 0)
df['log_cum_exp'] = [np.log(float(x)) for x in df['Cumulative_export']]
df['Cases_normalized'] = df['Cases_total']/df['Population_M']
df['Export_normalized'] = df['Exports_total']/df['Population_M']
df['Cumulative_export'] = [np.float(x) for x in df['Cumulative_export']]
df.head()
# Out:
#    Year Exports_total  Cases_total  Population_M  Cumulative_export  \
# 0  1981        217024       107433        225.65           217024.0
# 1  1982        297513       109391        228.00           514537.0
# 2  1983        269853       112454        230.39           784390.0
# 3  1984        264078       115819        232.77          1048468.0
# 4  1985        285068       120184        235.15          1333536.0
#
#    log_cum_exp  Cases_normalized Export_normalized
# 0    12.287763        476.104587        961.772657
# 1    13.151023        479.785088       1304.881579
# 2    13.572662        488.102782       1171.287816
# 3    13.862841        497.568415       1134.501869
# 4    14.103345        511.095046       1212.281522

# %%
plt.figure()
plt.scatter(df['Year'],df['Cases_normalized'])
plt.scatter(df['Year'],df['Cases_total']/200)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.scatter(df['Year'],df['Exports_total'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.scatter(df['Year'],df['Cumulative_export'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.scatter(df['Year'],df['Export_normalized'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.scatter(df['Year'],df['log_cum_exp'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.scatter(df['Cumulative_export'],df['Cases_normalized'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.scatter(df['Cumulative_export'],df['Cases_total'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
corr = np.correlate(df['Cumulative_export'],df['Cases_normalized'])
print(corr)
# Out:
# [1.39711357e+11]

# %%
np.corrcoef(df['Cases_total'],df['Cases_normalized'])
# Out:
# array([[1.        , 0.86574431],
#        [0.86574431, 1.        ]])

# %%
np.corrcoef(df['Cumulative_export'],df['Cases_normalized'])
#thus, it means that is a considerable correlation between the petroleum exports cummulated and the anual cases of cancer.
# Out:
# array([[1.        , 0.64399313],
#        [0.64399313, 1.        ]])

# %%
corr = np.corrcoef(df['Cumulative_export'],df['Cases_total'])
cor = corr[[1]][0][0]

# %%
df['Cumulative_export'].head()
df['Cases_total'].head()
# Out:
# 0    107433
# 1    109391
# 2    112454
# 3    115819
# 4    120184
# Name: Cases_total, dtype: int64

# %%
from matplotlib.ticker import ScalarFormatter
plt.figure(figsize=(12,8))
plt.plot(df['Cumulative_export']/1000000,df['Cases_total']/1000,'o-',markersize = 3, color = 'c', alpha = 0.7)
plt.xlabel('Cumulative exportation of crude oil plus petroleum derivates (x$10^9$barrels)'.format(1000000000))
plt.ylabel('Anual cancer cases (x$10^3$)')
plt.title('Cancer cases x cumulative petroleum exports (USA 1981 - 2016)')

for i, year in enumerate(df['Year']):
    plt.annotate(year,(df['Cumulative_export'][i]/1000000-0.3,df['Cases_total'][i]/1000-1),xytext=(10,5),textcoords='offset points', fontsize =8, ha ='center',color = 'black')
    
plt.grid(True, axis = 'both', alpha=0.3)

plt.xlim(0.0*df['Cumulative_export'].min()/1000000,1.02*df['Cumulative_export'].max()/1000000)
plt.ylim(0.98*df['Cases_total'].min()/1000,1.02*df['Cases_total'].max()/1000)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from matplotlib.ticker import ScalarFormatter
def figure_corr(xin, xfin)
    corr = np.corrcoef(df['Cumulative_export'][xin:xfin],df['Cases_total'][xin:xfin])
    cor = corr[[1]][0][0]
    
    plt.figure(figsize=(12,8))
    plt.plot(df['Cumulative_export']/1000000,df['Cases_total']/1000,'o-',markersize = 3, color = 'c', alpha = 0.7)
    plt.xlabel('Cumulative exportation of crude oil plus petroleum derivates (x$10^9$barrels)'.format(1000000000))
    plt.ylabel('Anual cancer cases (x$10^3$)')
    plt.title('Cancer cases x cumulative petroleum exports (USA 1981 - 2016)')

    for i, year in enumerate(df['Year']):
        plt.annotate(year,(df['Cumulative_export'][i]/1000000-0.3,df['Cases_total'][i]/1000-1),xytext=(10,5),textcoords='offset points', fontsize =8, ha ='center',color = 'black')

    plt.grid(True, axis = 'both', alpha=0.3)
    plt.xlim(0.0*df['Cumulative_export'].min()/1000000,1.02*df['Cumulative_export'].max()/1000000)
    plt.ylim(0.98*df['Cases_total'].min()/1000,1.02*df['Cases_total'].max()/1000)
    plt.show()
# Out:
#   Input In [35]
#     def figure_corr(xin, xfin)
#                               ^
# SyntaxError: invalid syntax

# %%
from matplotlib.ticker import ScalarFormatter
aa=df['Cumulative_export'].min()
ab=df['Cumulative_export'].max()
ba=df['Cases_total'].min()
bb=df['Cases_total'].max()

def figure_corr(xin, xfin):
    df_cum = df['Cumulative_export'].loc[(df['Year']>=xin) & (df['Year']<=xfin)]
    df_cas = df['Cases_total'].loc[(df['Year']>=xin) & (df['Year']<=xfin)]
    df_yea = df['Year'].loc[(df['Year']>=xin) & (df['Year']<=xfin)]
    
    corr = np.corrcoef(df_cum,df_cas)
    cor = round(corr[[1]][0][0],3)
    
    plt.figure(figsize=(12,8))
    plt.plot(df_cum/1000000,df_cas/1000,'o-',markersize = 3, color = 'c', alpha = 0.7)
    plt.xlabel('Cumulative exportation of crude oil plus petroleum derivates (x$10^9$barrels)'.format(1000000000))
    plt.ylabel('Anual cancer cases (x$10^3$)')
    plt.title('Cancer cases x cumulative petroleum exports (USA 1981 - 2016)')

    for i, year in enumerate(df_yea):
        plt.annotate(year,(df_cum[i]/1000000-0.3,df_cas[i]/1000-1),xytext=(10,5),textcoords='offset points', fontsize =8, ha ='center',color = 'black')

    plt.grid(True, axis = 'both', alpha=0.3)
    plt.xlim(0.0*aa/1000000,1.02*ab/1000000)
    plt.ylim(0.98*ba/1000,1.02*bb/1000)
    plt.text(0.7,0.1, "Cross correlation:{}".format(cor), fontsize =12, transform = plt.gca().transAxes)
    return plt.show()

# %%
#figure_corr(1981,2015)
df['Year']
# Out:
# 0     1981
# 1     1982
# 2     1983
# 3     1984
# 4     1985
# 5     1986
# 6     1987
# 7     1988
# 8     1989
# 9     1990
# 10    1991
# 11    1992
# 12    1993
# 13    1994
# 14    1995
# 15    1996
# 16    1997
# 17    1998
# 18    1999
# 19    2000
# 20    2001
# 21    2002
# 22    2003
# 23    2004
# 24    2005
# 25    2006
# 26    2007
# 27    2008
# 28    2009
# 29    2010
# 30    2011
# 31    2012
# 32    2013
# 33    2014
# 34    2015
# 35    2016
# Name: Year, dtype: int64

# %%
from matplotlib.ticker import ScalarFormatter
from ipywidgets import interact
import ipywidgets as widgets

aa=df['Cumulative_export'].min()
ab=df['Cumulative_export'].max()
ba=df['Cases_total'].min()
bb=df['Cases_total'].max()
minn = df['Year'].min()
maxx = df['Year'].max()

@interact(bounds = widgets.IntRangeSlider(
    value = [1990,2000],
    min = minn,
    max = maxx,
    step=1,
    description= 'Years Range:',
    continuous_update = False,
    readout_format='d',))

def figure_corr(bounds):
    #xin = int(xin)
    #xfin = int(xfin)
    #print(bounds[1])
   
    xin = int(bounds[0])
    xfin = int(bounds[1])
    #print(df.loc[df['Year']>=xin])
    #print(df.loc[(df['Year']>=xin) & (df['Year']<=xfin)])
    
    df_filtered = df.loc[(df['Year']>=xin) & (df['Year']<=xfin)]
    #print(df_filtered)
    #df_filtered = df.loc[(df['Year']>=int(bounds[0])) & (df['Year']<=int(bounds[1]))]
    
    df_cum = df_filtered['Cumulative_export']
    df_cas = df_filtered['Cases_total']
    df_yea = df_filtered['Year']
    
    #print(df_cum)
    
    corr = np.corrcoef(df_cum,df_cas)
    cor = round(corr[[1]][0][0],3)
    
    #print(cor)
    
    plt.figure(figsize=(8,5))
    plt.plot(df_cum/1000000,df_cas/1000,'o-',markersize = 3, color = 'c', alpha = 0.7)
    #print(df_cum/1000000,df_cas/1000)
    plt.xlabel('Cumulative exportation of crude oil plus petroleum derivates (x$10^9$barrels)'.format(1000000000))
    plt.ylabel('Anual cancer cases (x$10^3$)')
    plt.title('Cancer cases x cumulative petroleum exports (USA 1981 - 2016)')
    
    #if df_yea.min() == df['Year'].min():
    #    plt.annotate(df_yea.min(),(df_cum[0]/1000000-0.2,df_cas[0]/1000),xytext=(10,5),textcoords='offset points', fontsize =8, ha ='center',color = 'black')
    for i, year in zip(df_cum.index,df_yea):
        #print(df_yea)
        #print(df_cum[i])
        plt.annotate(year,(df_cum[i]/1000000-0.3,df_cas[i]/1000-1),xytext=(10,5),textcoords='offset points', fontsize =8, ha ='center',color = 'black')
        #print(year,i)

    plt.grid(True, axis = 'both', alpha=0.3)
    plt.xlim(aa/1000000-1,ab/1000000+1)
    plt.ylim(0.98*ba/1000,1.02*bb/1000)
    plt.text(0.6,0.1, "Cross correlation:{}".format(cor), fontsize =12, transform = plt.gca().transAxes, color = "c")
    return plt.show()

#figure_corr(3,1981,2015)
# Out:
# interactive(children=(IntRangeSlider(value=(1990, 2000), continuous_update=False, description='Years Range:', …
